# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

import gradio as gr


#read 
import pandas as pd
import numpy as np

import requests
import pandas as pd
import nltk


import json


from PIL import Image
from io import BytesIO


from PIL import Image, ImageFilter, ImageOps
from matplotlib import pyplot as plt





class BearerAuth(requests.auth.AuthBase):
    def __init__(self, token):
        self.token = token
    def __call__(self, r):
        r.headers["authorization"] = "Bearer " + self.token
        return r
    

from LDA_model_utils import *
from gradio_utils import *

# %% [markdown]
# # Yelp API Call

# %%
site="https://api.yelp.com/v3/businesses/north-india-restaurant-san-francisco/reviews"

# %%
apiRestQueryTest(site)
# Out:
# 'Everything is so delicious! We came for my friends birthday and had the best experience, our server really made it so special.'

# %%
gr.Interface(fn=apiRestQueryTest, 
             inputs='textbox', 
             outputs='textbox').launch(share=True);
# Out:
# Running on local URL:  http://127.0.0.1:7862/
# Running on public URL: https://57926.gradio.app
#
# This share link will expire in 72 hours. To get longer links, send an email to: support@gradio.app
#         <iframe
#             width="900"
#             height="500"
#             src="https://57926.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Yelp API photo request
# Extract an image_url from a site for given restaurant

# %%
gr.Interface(fn=callImageRestAPI, 
             inputs='textbox', 
             outputs="image").launch(share=True);
# Out:
# Running on local URL:  http://127.0.0.1:7863/
# Running on public URL: https://30003.gradio.app
#
# This share link will expire in 72 hours. To get longer links, send an email to: support@gradio.app
#         <iframe
#             width="900"
#             height="500"
#             src="https://30003.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Feature Extraction with SIFT

# %%
gr.Interface(fn=draw_keyp_sift_test, inputs=gr.inputs.Image(shape=(299, 299)), 
             outputs=gr.outputs.Image(type="auto", label=None)
             ).launch(share=True);
# Out:
# Running on local URL:  http://127.0.0.1:7865/
# Running on public URL: https://58353.gradio.app
#
# This share link will expire in 72 hours. To get longer links, send an email to: support@gradio.app
#         <iframe
#             width="900"
#             height="500"
#             src="https://58353.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Feature Extraction with ORB

# %%
gr.Interface(fn=draw_keyp_orb_test, inputs=gr.inputs.Image(shape=(299, 299)), 
             outputs=gr.outputs.Image(type="auto", label=None)
             ).launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7866/
# Running on public URL: https://27443.gradio.app
#
# This share link will expire in 72 hours. To get longer links, send an email to: support@gradio.app
#         <iframe
#             width="900"
#             height="500"
#             src="https://27443.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<Flask 'gradio.networking'>,
#  'http://127.0.0.1:7866/',
#  'https://27443.gradio.app')

# %% [markdown]
# # TOPIC Visualization

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1      0.270562 -0.129951       1        1  40.127142
# 2      0.057944  0.265825       2        1  30.513594
# 3     -0.127240 -0.102531       3        1  14.766870
# 0     -0.201267 -0.033343       4        1  14.592394, topic_info=        Term        Freq       Total Category  logprob  loglift
# 43      food  588.000000  588.000000  Default  30.0000  30.0000
# 57     order  518.000000  518.000000  Default  29.0000  29.0000
# 544     tell  324.000000  324.000000  Default  28.0000  28.0000
# 30     place  467.000000  467.000000  Default  27.0000  27.0000
# 315     wait  357.000000  357.000000  Default  26.0000  26.0000
# ..       ...         ...         ...      ...      ...      ...
# 126     back   93.069844  371.758774   Topic4  -4.4096   0.5398
# 63     bring   55.543706  109.691823   Topic4  -4.9258   1.2442
# 473      way   54.447477  133.330680   Topic4  -4.9457   1.0291
# ...
